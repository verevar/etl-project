# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
import os
import datetime as dt

# %%
nat_disasters_path = "Natural disasters.csv"
nat_disasters_cost_path = "disaster_cost.csv"
nat_disastersdata = pd.read_csv(nat_disasters_path)
nat_disastercost = pd.read_csv(nat_disasters_cost_path)

# %%
nd_ca = nat_disastercost.loc[(nat_disastercost['state'] == "CA")]
nd_ca
# Out:
#      Year                              incident_type Death toll  \
# 9    2020                                   Wildfire         47
# 10   2020                                   Wildfire         31
# 19   2019                                 Earthquake          1
# 21   2018                                   Wildfire         97
# 22   2018                                   Wildfire         85
# 26   2017                                   Wildfire         47
# 31   2017                     Winter storm and flood          5
# 63   2007                                   Wildfire         14
# 64   2006                                  Wildfires          9
# 76   2003                                   Wildfire         15
# 87   1994                                 Earthquake         57
# 92   1991                                   Wildfire         25
# 94   1989                                 Earthquake         69
# 108  1971                                 Earthquake         65
# 121  1938                                      Flood        115
# 137  1906  Earthquake and fire (urban conflagration)       6000
# 147  1862                                      Flood       5000
#
#     Damage cost (billions USD)                                Main article  \
# 9                       19.884  2020 Western United States wildfire season
# 10                      12.079                   2020 California wildfires
# 19                         5.3                 2019 Ridgecrest earthquakes
# 21                      26.347                   2018 California wildfires
# 22                        16.5                                   Camp Fire
# 26                          18                   2017 California wildfires
# 31                        1.55                      2017 California floods
# 63                       2.393           October 2007 California wildfires
# 64                      0.2266                   2006 California wildfires
# 76                       1.331                                  Cedar Fire
# 87           23,000,000,000.00                       Northridge earthquake
# 92            1,500,000,000.00                          Oakland Hills fire
# 94            6,000,000,000.00                      Loma Prieta earthquake
# 108             500,000,000.00                           Sylmar earthquake
# 121                        NaN                   Los Angeles Flood of 1938
# 137                        NaN               1906 San Francisco earthquake
# 147             100,000,000.00                         Great Flood of 1862
#
#     state                                              Notes
# 9      CA  One of the most destructive wildfire seasons r...
# 10     CA  The largest and the third-most destructive wil...
# 19     CA  Three earthquakes struck California between Ju...
# 21     CA  The deadliest and most destructive wildfire se...
# 22     CA  The worst fire in California history destroyed...
# 26     CA  The second-most destructive wildfire season on...
# 31     CA  Caused by a series of storms that led to Calif...
# 63     CA  Large fires burned out of control across south...
# 64     CA                                                NaN
# 76     CA  The largest and most destructive wildfire reco...
# 87     CA                                                NaN
# 92     CA                                                NaN
# 94     CA                                                NaN
# 108    CA                                                NaN
# 121    CA                                                NaN
# 137    CA  Conflagration followed quake; fatalities estim...
# 147    CA  An atmospheric river led to 43 continuous days...

# %%
curr_nat_dis_cost = nd_ca.drop(nd_ca[nd_ca.Year < "2000"].index)
curr_nat_dis_cost
# Out:
#     Year           incident_type Death toll Damage cost (billions USD)  \
# 9   2020                Wildfire         47                     19.884
# 10  2020                Wildfire         31                     12.079
# 19  2019              Earthquake          1                        5.3
# 21  2018                Wildfire         97                     26.347
# 22  2018                Wildfire         85                       16.5
# 26  2017                Wildfire         47                         18
# 31  2017  Winter storm and flood          5                       1.55
# 63  2007                Wildfire         14                      2.393
# 64  2006               Wildfires          9                     0.2266
# 76  2003                Wildfire         15                      1.331
#
#                                   Main article state  \
# 9   2020 Western United States wildfire season    CA
# 10                   2020 California wildfires    CA
# 19                 2019 Ridgecrest earthquakes    CA
# 21                   2018 California wildfires    CA
# 22                                   Camp Fire    CA
# 26                   2017 California wildfires    CA
# 31                      2017 California floods    CA
# 63           October 2007 California wildfires    CA
# 64                   2006 California wildfires    CA
# 76                                  Cedar Fire    CA
#
#                                                 Notes
# 9   One of the most destructive wildfire seasons r...
# 10  The largest and the third-most destructive wil...
# 19  Three earthquakes struck California between Ju...
# 21  The deadliest and most destructive wildfire se...
# 22  The worst fire in California history destroyed...
# 26  The second-most destructive wildfire season on...
# 31  Caused by a series of storms that led to Calif...
# 63  Large fires burned out of control across south...
# 64                                                NaN
# 76  The largest and most destructive wildfire reco...

# %%
curr_nat_dis_cost["Damage cost (billions USD)"]=curr_nat_dis_cost["Damage cost (billions USD)"].astype(float)

# %%
yearly_nat_disastercost_ca = curr_nat_dis_cost.groupby('Year')['Damage cost (billions USD)'].sum()
yearly_nat_disastercost_ca = pd.DataFrame(data=yearly_nat_disastercost_ca)
yearly_nat_disastercost_ca
# Out:
#       Damage cost (billions USD)
# Year
# 2003                      1.3310
# 2006                      0.2266
# 2007                      2.3930
# 2017                     19.5500
# 2018                     42.8470
# 2019                      5.3000
# 2020                     31.9630

# %%
# x_line = yearly_nat_disastercost_ca["Year"]
# y_line = yearly_nat_disastercost_ca["Damage cost (billions USD)"]

# line_graph, = plt.plot(x_line, y_line, color="blue")
# plt.title("Natural Disaster Cost per Year in California")
# plt.xlabel("Year")
# plt.ylabel("Damage cost (billions USD)")
# plt.legend(handles=[line_graph], loc="best")
# plt.show()

yearly_nat_disastercost_ca.plot(kind="bar")
plt.xlabel("Year")
plt.xticks(rotation=45)
plt.ylabel("Damage Cost (billions USD)")
plt.title("Natural Disaster Cost per Year in California")
plt.legend("")
plt.show()

# %%
nd_tx = nat_disastercost.loc[(nat_disastercost['state'] == "TX")]
nd_tx
# Out:
#      Year        incident_type Death toll Damage cost (billions USD)  \
# 8    2021         Winter storm        237                      196.5
# 11   2020            Hurricane        331                        7.9
# 12   2020            Hurricane          8                        3.6
# 13   2020            Hurricane          6                      3.086
# 14   2020            Hurricane          8                        7.3
# 15   2020            Hurricane         77                       19.1
# 17   2020            Hurricane          9                        1.2
# 18   2019       Tropical storm          7                          5
# 30   2017  Hurricane and Flood        107                        125
# 41   2015                Flood         46                        NaN
# 60   2008            Hurricane        113                         38
# 61   2008            Hurricane         53                       8.31
# 68   2005            Hurricane        120                         10
# 71   2004            Hurricane        124                         19
# 77   2001            Hurricane         41                        5.5
# 80   1999              Tornado         48                 1500000000
# 100  1983            Hurricane         21                 3000000000
# 101  1980            Hurricane          6                  630000000
# 102  1980            Heat wave       1700                20000000000
# 109  1970              Tornado         26                 1412000000
# 115  1953              Tornado        114                        NaN
# 130  1919            Hurricane        600                        NaN
# 138  1900            Hurricane      12000                   35400000
#
#                                          Main article state  \
# 8    February 13–17, 2021 North American winter storm    TX
# 11                                      Hurricane Eta    TX
# 12                                     Hurricane Zeta    TX
# 13                                    Hurricane Delta    TX
# 14                                    Hurricane Sally    TX
# 15                                    Hurricane Laura    TX
# 17                                    Hurricane Hanna    TX
# 18                              Tropical Storm Imelda    TX
# 30                                   Hurricane Harvey    TX
# 41                         2015 Texas–Oklahoma floods    TX
# 60                                      Hurricane Ike    TX
# 61                                   Hurricane Gustav    TX
# 68                                     Hurricane Rita    TX
# 71                                     Hurricane Ivan    TX
# 77                             Tropical Storm Allison    TX
# 80                     1999 Oklahoma tornado outbreak    TX
# 100                                  Hurricane Alicia    TX
# 101                                   Hurricane Allen    TX
# 102                      1980 United States heat wave    TX
# 109                                   Lubbock Tornado    TX
# 115                                               NaN    TX
# 130                       1919 Florida Keys Hurricane    TX
# 138                       Galveston Hurricane of 1900    TX
#
#                                                  Notes
# 8    While the storm was widespread across the U.S....
# 11   Long-lived tropical cyclone that made four lan...
# 12                                            [11][16]
# 13                                            [11][16]
# 14   Sally did not have its name retired, making it...
# 15   Tied with the 1856 Last Island hurricane as th...
# 17                                                [11]
# 18   The fifth-wettest tropical cyclone recorded in...
# 30   Harvey made landfall in Southwestern Texas as ...
# 41                                                 NaN
# 60   At the time, Ike was the costliest natural dis...
# 61                                                 NaN
# 68                                                 NaN
# 71                                                 NaN
# 77                                                 NaN
# 80                                        74 tornadoes
# 100                                                NaN
# 101                                                NaN
# 102  Official death toll, may have been higher; dam...
# 109  F5 tornado killed 26 and wounded approximately...
# 115                                                NaN
# 130                                                NaN
# 138  Fatalities estimated – remains deadliest natur...

# %%
curr_nat_dis_cost_tx = nd_tx.drop(nd_tx[nd_tx.Year < "2000"].index)
curr_nat_dis_cost_tx
# Out:
#     Year        incident_type Death toll Damage cost (billions USD)  \
# 8   2021         Winter storm        237                      196.5
# 11  2020            Hurricane        331                        7.9
# 12  2020            Hurricane          8                        3.6
# 13  2020            Hurricane          6                      3.086
# 14  2020            Hurricane          8                        7.3
# 15  2020            Hurricane         77                       19.1
# 17  2020            Hurricane          9                        1.2
# 18  2019       Tropical storm          7                          5
# 30  2017  Hurricane and Flood        107                        125
# 41  2015                Flood         46                        NaN
# 60  2008            Hurricane        113                         38
# 61  2008            Hurricane         53                       8.31
# 68  2005            Hurricane        120                         10
# 71  2004            Hurricane        124                         19
# 77  2001            Hurricane         41                        5.5
#
#                                         Main article state  \
# 8   February 13–17, 2021 North American winter storm    TX
# 11                                     Hurricane Eta    TX
# 12                                    Hurricane Zeta    TX
# 13                                   Hurricane Delta    TX
# 14                                   Hurricane Sally    TX
# 15                                   Hurricane Laura    TX
# 17                                   Hurricane Hanna    TX
# 18                             Tropical Storm Imelda    TX
# 30                                  Hurricane Harvey    TX
# 41                        2015 Texas–Oklahoma floods    TX
# 60                                     Hurricane Ike    TX
# 61                                  Hurricane Gustav    TX
# 68                                    Hurricane Rita    TX
# 71                                    Hurricane Ivan    TX
# 77                            Tropical Storm Allison    TX
#
#                                                 Notes
# 8   While the storm was widespread across the U.S....
# 11  Long-lived tropical cyclone that made four lan...
# 12                                           [11][16]
# 13                                           [11][16]
# 14  Sally did not have its name retired, making it...
# 15  Tied with the 1856 Last Island hurricane as th...
# 17                                               [11]
# 18  The fifth-wettest tropical cyclone recorded in...
# 30  Harvey made landfall in Southwestern Texas as ...
# 41                                                NaN
# 60  At the time, Ike was the costliest natural dis...
# 61                                                NaN
# 68                                                NaN
# 71                                                NaN
# 77                                                NaN

# %%
curr_nat_dis_cost_tx["Damage cost (billions USD)"]=curr_nat_dis_cost_tx["Damage cost (billions USD)"].astype(float)

# %%
yearly_nat_disastercost_tx = curr_nat_dis_cost_tx.groupby('Year')['Damage cost (billions USD)'].sum()
yearly_nat_disastercost_tx = pd.DataFrame(data=yearly_nat_disastercost_tx)
yearly_nat_disastercost_tx
# Out:
#       Damage cost (billions USD)
# Year
# 2001                       5.500
# 2004                      19.000
# 2005                      10.000
# 2008                      46.310
# 2015                       0.000
# 2017                     125.000
# 2019                       5.000
# 2020                      42.186
# 2021                     196.500

# %%
yearly_nat_disastercost_tx.plot(kind="bar")
plt.xlabel("Year")
plt.xticks(rotation=45)
plt.ylabel("Damage Cost (billions USD)")
plt.title("Natural Disaster Cost per Year in Texas")
plt.legend("")
plt.show()

# %%
nat_disastersdata["Year"]=nat_disastersdata["Year"].astype(str)
nat_disastersdata["Year"].describe()
# Out:
# count     63030
# unique       70
# top        2020
# freq       9490
# Name: Year, dtype: object

# %%
nat_dis_ca = nat_disastersdata.loc[(nat_disastersdata['state'] == "CA")]
nat_dis_ca
# Out:
#        Year fema_declaration_string  disaster_number state declaration_type  \
# 13     1954                DR-15-CA               15    CA               DR
# 45     1956                DR-47-CA               47    CA               DR
# 63     1957                DR-65-CA               65    CA               DR
# 80     1958                DR-82-CA               82    CA               DR
# 117    1962               DR-119-CA              119    CA               DR
# ...     ...                     ...              ...   ...              ...
# 62478  2021              DR-4619-CA             4619    CA               DR
# 62479  2021              DR-4619-CA             4619    CA               DR
# 62548  2021              FM-5417-CA             5417    CA               FM
# 62567  2022              FM-5419-CA             5419    CA               FM
# 62999  2022              FM-5439-CA             5439    CA               FM
#
#            declaration_date incident_type          declaration_title  \
# 13     1954-02-05T00:00:00Z         Flood            Flood & Erosion
# 45     1955-12-23T00:00:00Z         Flood                      Flood
# 63     1956-12-29T00:00:00Z          Fire                Forest Fire
# 80     1958-04-04T00:00:00Z         Flood   Heavy Rainstorms & Flood
# 117    1961-11-16T00:00:00Z          Fire  Fire (Los Angeles County)
# ...                     ...           ...                        ...
# 62478  2021-09-12T21:12:00Z          Fire                  Wildfires
# 62479  2021-09-12T21:12:00Z          Fire                  Wildfires
# 62548  2021-09-23T21:00:00Z          Fire                  Fawn Fire
# 62567  2021-10-13T00:46:00Z          Fire                Alisal Fire
# 62999  2022-05-12T00:56:00Z          Fire               Coastal Fire
#
#        ih_program_declared  ia_program_declared  ...     incident_end_date  \
# 13                       0                    1  ...  1954-02-05T00:00:00Z
# 45                       0                    1  ...  1955-12-23T00:00:00Z
# 63                       0                    1  ...  1956-12-29T00:00:00Z
# 80                       0                    1  ...  1958-04-04T00:00:00Z
# 117                      0                    1  ...  1961-11-16T00:00:00Z
# ...                    ...                  ...  ...                   ...
# 62478                    0                    0  ...  2021-10-21T23:59:00Z
# 62479                    0                    0  ...  2021-10-21T23:59:00Z
# 62548                    0                    0  ...  2021-09-28T23:59:00Z
# 62567                    0                    0  ...  2021-11-17T23:59:00Z
# 62999                    0                    0  ...                   NaN
#
#        disaster_closeout_date  fips place_code         designated_area  \
# 13       1957-09-01T00:00:00Z  6000          0               Statewide
# 45       1968-08-12T00:00:00Z  6000          0               Statewide
# 63       1959-04-01T00:00:00Z  6000          0               Statewide
# 80       1961-08-01T00:00:00Z  6000          0               Statewide
# 117      1963-08-01T00:00:00Z  6000          0               Statewide
# ...                       ...   ...        ...                     ...
# 62478                     NaN  6017      99017      El Dorado (County)
# 62479                     NaN  6033      99033           Lake (County)
# 62548                     NaN  6089      99089         Shasta (County)
# 62567                     NaN  6083      99083  Santa Barbara (County)
# 62999                     NaN  6059      99059         Orange (County)
#
#        declaration_request_number  last_ia_filing_date  \
# 13                          54016                  NaN
# 45                          55018                  NaN
# 63                          56018                  NaN
# 80                          58012                  NaN
# 117                         61019                  NaN
# ...                           ...                  ...
# 62478                       21100                  NaN
# 62479                       21100                  NaN
# 62548                       21107                  NaN
# 62567                       21115                  NaN
# 62999                       22042                  NaN
#
#                                            hash          last_refresh  \
# 13     8fbe16b1e789e3ab669ed767631dd92214d900ee  2022-04-26T19:03:06Z
# 45     d2b4c41dd5a8c788c0947409ceafc0a38012d880  2022-04-26T19:03:06Z
# 63     dd41bfa6d3b968b886241fcd7c323ee2c4d2b99d  2022-04-26T19:03:06Z
# 80     0918fba764a8413274b50ff20d71bc3aadfa6580  2022-04-26T19:03:06Z
# 117    7d68df7f3ce292f6cac656cada6ff134b2a3f785  2022-04-26T19:03:06Z
# ...                                         ...                   ...
# 62478  d257349b743aab72adccde0bdd275f17393e2c0f  2022-04-26T19:01:18Z
# 62479  635f1f0a9510a47b85816e14a79a3e1907252e6a  2022-04-26T19:01:18Z
# 62548  7e00c62162139d0be24f6c942d376723cee2f610  2022-04-26T19:01:16Z
# 62567  8b03c3a96668f5392220482186c6113439ee248f  2022-04-26T19:01:16Z
# 62999  3867f4373c1b451767f78c6e0aac17b9ed2d1b73  2022-05-12T18:22:01Z
#
#                              id
# 13     60c3b7a9a0ee349d710258b6
# 45     60c3b7a9a0ee349d710259cc
# 63     60c3b7aaa0ee349d71025f20
# 80     60c3b7aaa0ee349d7102609f
# 117    60c3b7aba0ee349d71026678
# ...                         ...
# 62478  613eac6f434e34d5ee194ec1
# 62479  61b93ec5ca68100bde83aee1
# 62548  614e8374b7c535bbb1907259
# 62567  61673b33b7c535bbb16bb63a
# 62999  627d504acb1b3a789cc8cefe
#
# [1466 rows x 23 columns]

# %%
curr_nat_dis_ca = nat_dis_ca.drop(nat_dis_ca[nat_dis_ca.Year < "2000"].index)
# curr_nat_dis_ca

yearly_nat_dis_cal = curr_nat_dis_ca.groupby("Year")
curr_nat_dis_ca_total = yearly_nat_dis_cal["Year"].count()
# curr_nat_dis_ca_total

curr_nat_dis_ca_total_df = pd.DataFrame(curr_nat_dis_ca_total)
curr_nat_dis_ca_total_df = curr_nat_dis_ca_total_df.rename(columns={"Year": "Number of Natural Disasters"})
curr_nat_dis_ca_total_df
# Out:
#       Number of Natural Disasters
# Year
# 2000                            1
# 2002                           14
# 2003                            8
# 2004                           40
# 2005                           79
# 2006                           58
# 2007                           27
# 2008                           49
# 2009                           22
# 2010                           14
# 2011                           17
# 2012                            5
# 2013                            9
# 2014                           19
# 2015                           14
# 2016                           14
# 2017                          115
# 2018                           54
# 2019                           44
# 2020                          175
# 2021                           38
# 2022                            2

# %%
nat_dis_tx = nat_disastersdata.loc[(nat_disastersdata['state'] == "TX")]
nat_dis_tx
# Out:
#        Year fema_declaration_string  disaster_number state declaration_type  \
# 1      1953                 DR-2-TX                2    TX               DR
# 8      1953                 DR-9-TX                9    TX               DR
# 16     1954                DR-18-TX               18    TX               DR
# 70     1957                DR-72-TX               72    TX               DR
# 83     1958                DR-85-TX               85    TX               DR
# ...     ...                     ...              ...   ...              ...
# 62942  2022              FM-5427-TX             5427    TX               FM
# 62943  2022              FM-5428-TX             5428    TX               FM
# 62944  2022              FM-5429-TX             5429    TX               FM
# 63006  2022              FM-5440-TX             5440    TX               FM
# 63007  2022              FM-5440-TX             5440    TX               FM
#
#            declaration_date incident_type  \
# 1      1953-05-15T00:00:00Z       Tornado
# 8      1953-06-19T00:00:00Z         Flood
# 16     1954-07-01T00:00:00Z         Flood
# 70     1957-04-29T00:00:00Z     Hurricane
# 83     1958-06-06T00:00:00Z       Tornado
# ...                     ...           ...
# 62942  2022-03-17T23:46:00Z          Fire
# 62943  2022-03-18T02:56:00Z          Fire
# 62944  2022-03-20T21:25:00Z          Fire
# 63006  2022-05-18T23:43:00Z          Fire
# 63007  2022-05-18T23:43:00Z          Fire
#
#                           declaration_title  ih_program_declared  \
# 1                  Tornado & Heavy Rainfall                    0
# 8                                     Flood                    0
# 16                                    Flood                    0
# 70     Hurricane, Rain, Wind, Hail & Floods                    0
# 83           Tornadoes, Rain, Hail & Floods                    0
# ...                                     ...                  ...
# 62942                             Kidd Fire                    0
# 62943                      Wheat Field Fire                    0
# 62944                            Big L Fire                    0
# 63006                    Mesquite Heat Fire                    0
# 63007                    Mesquite Heat Fire                    0
#
#        ia_program_declared  ...     incident_end_date  disaster_closeout_date  \
# 1                        1  ...  1953-05-15T00:00:00Z    1958-01-01T00:00:00Z
# 8                        1  ...  1953-06-19T00:00:00Z    1958-01-01T00:00:00Z
# 16                       1  ...  1954-07-01T00:00:00Z    1959-07-01T00:00:00Z
# 70                       1  ...  1957-04-29T00:00:00Z    1961-03-01T00:00:00Z
# 83                       1  ...  1958-06-06T00:00:00Z    1961-03-01T00:00:00Z
# ...                    ...  ...                   ...                     ...
# 62942                    0  ...  2022-03-30T23:59:00Z                     NaN
# 62943                    0  ...  2022-03-30T23:59:00Z                     NaN
# 62944                    0  ...  2022-03-30T23:59:00Z                     NaN
# 63006                    0  ...                   NaN                     NaN
# 63007                    0  ...                   NaN                     NaN
#
#         fips place_code    designated_area  declaration_request_number  \
# 1      48000          0          Statewide                       53003
# 8      48000          0          Statewide                       53010
# 16     48000          0          Statewide                       54004
# 70     48000          0          Statewide                       57018
# 83     48000          0          Statewide                       58016
# ...      ...        ...                ...                         ...
# 62942  48133      99133  Eastland (County)                       22022
# 62943  48133      99133  Eastland (County)                       22023
# 62944  48221      99221      Hood (County)                       22024
# 63006  48000          0          Statewide                       22043
# 63007  48441      99441    Taylor (County)                       22043
#
#        last_ia_filing_date                                      hash  \
# 1                      NaN  8784655a1395087b17c39b9f7422a5fd1db7826d
# 8                      NaN  02a3dfd32ad8681b771da51d4bfc859094201a90
# 16                     NaN  f0c5e5ee55c7968cfbeefb72d2e2eb2aac89dee4
# 70                     NaN  2942cc4a22a21735e0d2d89d038528c567f10872
# 83                     NaN  8017d0d2f6aa73c6060744dffdad0e1e6c394ffc
# ...                    ...                                       ...
# 62942                  NaN  a13ade50a1031c7e1473b5c3b931a5ba6cac301e
# 62943                  NaN  046cd48a909dddae058aa3fac4dcaa24d9830e50
# 62944                  NaN  489786783e8dd39c7d5ba04899572edb143e78b4
# 63006                  NaN  e5b7cfcdb78ddd76b07a3eb4cbd435abf5a7870c
# 63007                  NaN  4dec9fca0a581b93aee83bd2eec0033df4b186d6
#
#                last_refresh                        id
# 1      2022-04-26T19:03:06Z  60c3b7a9a0ee349d71025783
# 8      2022-04-26T19:03:06Z  60c3b7a9a0ee349d71025759
# 16     2022-04-26T19:03:06Z  60c3b7a9a0ee349d710257e0
# 70     2022-04-26T19:03:06Z  60c3b7aaa0ee349d71026032
# 83     2022-04-26T19:03:06Z  60c3b7aaa0ee349d710261dd
# ...                     ...                       ...
# 62942  2022-04-26T19:01:16Z  6234f38ecbab24a500509c3c
# 62943  2022-04-26T19:01:16Z  6234f38ecbab24a500509c3b
# 62944  2022-04-26T19:01:16Z  623893b2cbab24a50042ffe5
# 63006  2022-05-19T14:02:05Z  62864ddd8311f76a9afe7315
# 63007  2022-05-19T14:22:04Z  6286528c8311f76a9aff243c
#
# [5171 rows x 23 columns]

# %%
curr_nat_dis_tx = nat_dis_tx.drop(nat_dis_tx[nat_dis_tx.Year < "2000"].index)
# curr_nat_dis_tx

yearly_nat_dis_tx = curr_nat_dis_tx.groupby("Year")
curr_nat_dis_tx_total = yearly_nat_dis_tx["Year"].count()
# curr_nat_dis_tx_total

curr_nat_dis_tx_total_df = pd.DataFrame(curr_nat_dis_tx_total)
curr_nat_dis_tx_total_df = curr_nat_dis_tx_total_df.rename(columns={"Year": "Number of Natural Disasters"})
curr_nat_dis_tx_total_df
# Out:
#       Number of Natural Disasters
# Year
# 2000                           20
# 2001                           80
# 2002                           52
# 2003                           90
# 2005                          763
# 2006                          277
# 2007                          116
# 2008                          476
# 2009                           16
# 2010                           46
# 2011                          261
# 2012                            1
# 2013                            2
# 2014                            5
# 2015                          113
# 2016                          168
# 2017                           53
# 2018                            9
# 2019                           40
# 2020                          616
# 2021                          513
# 2022                            7
