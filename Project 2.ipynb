# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
import os
import datetime as dt

# %%
nat_disasters_path = "Natural disasters.csv"
nat_disastersdata = pd.read_csv(nat_disasters_path)
nat_disastersdata
# Out:
#       fema_declaration_string  disaster_number state declaration_type  \
# 0                     DR-1-GA                1    GA               DR
# 1                     DR-2-TX                2    TX               DR
# 2                     DR-3-LA                3    LA               DR
# 3                     DR-4-MI                4    MI               DR
# 4                     DR-5-MT                5    MT               DR
# ...                       ...              ...   ...              ...
# 63025              DR-4654-KS             4654    KS               DR
# 63026              DR-4654-KS             4654    KS               DR
# 63027              DR-4654-KS             4654    KS               DR
# 63028              DR-4654-KS             4654    KS               DR
# 63029              FM-5441-AZ             5441    AZ               FM
#
#            declaration_date  fy_declared incident_type  \
# 0      1953-05-02T00:00:00Z         1953       Tornado
# ...

# %%
sum_value_df = nat_disastersdata.groupby('incident_type').sum()
sum_value_df
# Out:
#                   disaster_number  fy_declared  ih_program_declared  \
# incident_type
# Biological               31546241     15871142                 4115
# Chemical                    30294        18126                    0
# Coastal Storm             1775606      1281834                    0
# Dam/Levee Break             41997        26132                    5
# Drought                   3711601      2556338                    0
# Earthquake                 613507       456022                   59
# Fire                     10553491      7208781                  167
# Fishing Losses              49022        83284                    0
# Flood                    16332972     20931369                  595
# Freezing                   276548       598748                    0
# Human Cause                 17463        13903                    0
# Hurricane                36987303     25085985                 1655
# Mud/Landslide              144926        72528                    4
# ...
